# %%
import cv2

# %%
test_image = cv2.imread('C:\\Users\\Swathi priya\\OneDrive\\Documents\\Dogs-vs-Cats_classifier\\Prediction\\pics\\Cat.jpg')

# %%
import matplotlib.pyplot as plt

plt.imshow(test_image)

# %%
test_image.shape
# Out:
# (803, 1200, 3)

# %%
test_image = cv2.resize(test_image,(256,256))

# %%
test_input = test_image.reshape((1,256,256,3))
